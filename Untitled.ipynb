# %%
import pandas as pd

# %%
df_1998=pd.read_csv('data_1998.csv', sep=';')
df_2018=pd.read_csv('data_2018.csv', sep=';')
df_1998
df_2018
# Out:
#         Nom du joueur             Postes  Arrêts  Nombre de but  \
# 0   Antoine Griezmann          Attaquant     NaN            4.0
# 1        Thomas Lemar          Attaquant     NaN            NaN
# 2      Olivier Giroud          Attaquant     NaN            NaN
# 3       Kylian Mbappé          Attaquant     NaN            4.0
# 4     Ousmane Dembélé          Attaquant     NaN            NaN
# 5         Nabil Fekir          Attaquant     NaN            NaN
# 6     Florian Thauvin          Attaquant     NaN            NaN
# 7     Benjamin Pavard          Défenseur     NaN            1.0
# 8    Presnel Kimpembe          Défenseur     NaN            NaN
# 9      Raphaël Varane          Défenseur     NaN            1.0
# 10      Samuel Umtiti          Défenseur     NaN            1.0
# 11          Adil Rami          Défenseur     NaN            NaN
# 12    Lucas Hernandez          Défenseur     NaN            NaN
# 13     Benjamin Mendy          Défenseur     NaN            NaN
# ...

# %%
df_1998 = df_1998.drop("Défense", axis='columns')
df_1998 = df_1998.drop("Coup francs", axis='columns')
df_1998 = df_1998.drop("Corner", axis='columns')
df_1998
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 df = df.drop("Défense", axis='columns')
#       2 df = df.drop("Coup francs", axis='columns')
#       3 df = df.drop("Corner", axis='columns')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
number_goals=df_1998['Nombre de but'].sum()
print('Total de but en 1998 :',number_goals)
number_assist=df_1998['Nombre de passe décisive'].sum()
print('Total de passes décisives en 1998 :',number_assist)
number_yellow_card=df_1998['Carton jaune'].sum()
print('Total de cartons jaunes en 1998 :',number_yellow_card)
# Out:
# Total de but en 1998 : 15.0
# Total de passes décisives en 1998 : 8.0
# Total de cartons jaunes en 1998 : 12.0

# %%
# Out:
#          Nom du joueur             Postes Arrêts  Nombre de but  \
# 0        Thierry Henry          Attaquant    NaN            3.0
# 1      David Trezeguet          Attaquant    NaN            2.0
# 2   Christophe Dugarry          Attaquant    NaN            1.0
# 3   Stéphane Guivarc'h          Attaquant    NaN            NaN
# 4      Vincent Candela          Défenseur    NaN            NaN
# 5        Lilian Thuram          Défenseur    NaN            2.0
# 6        Laurent Blanc          Défenseur    NaN            1.0
# 7         Frank Lebœuf          Défenseur    NaN            NaN
# 8     Bixente Lizarazu          Défenseur    NaN            1.0
# 9      Marcel Desailly          Défenseur    NaN            NaN
# 10  Lionel Charbonnier     Gardien de but    NaN            NaN
# 11      Fabien Barthez     Gardien de but     23            NaN
# 12        Bernard Lama     Gardien de but    NaN            NaN
# 13     Zinédine Zidane  Milieu de terrain    NaN            2.0
# ...

# %%
# Out:
# 8.0

# %%
# Out:
# 12.0
